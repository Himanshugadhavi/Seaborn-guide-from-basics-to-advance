# %% [markdown]
# # Why Seaborn?
# * provides a layer of abstraction hence simpler to use
# * better aesthetics
# * more graphs included

# %% [markdown]
# ### Seaborn Roadmap
#
# Types of Functions
#
# - Figure Level
# - Axis Level
#
# Main Classification
#
# - Relational Plot
# - Distribution Plot
# - Categorical Plot
# - Regression Plot
# - Matrix Plot
# - Multiplots
#
# https://seaborn.pydata.org/api.html

# %% [markdown]
# ## `1. Relational Plot`
#
# - to see the statistical relation between 2 or more variables.
# - Bivariate Analysis
#
# Plots under this section
#
# - scatterplot
# - lineplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
'''we will imoort the existing dataset,
which is inside the seaborn library, named - tips'''

sns.load_dataset('tips')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips = sns.load_dataset('tips')
# saving the dataset in the tips variable

# %% [markdown]
# ### scatter plot

# %% [markdown]
# >* scatter plot -> axes level function

# %%
sns.scatterplot(data=tips, x='total_bill',y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip',hue='sex')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip',hue='sex',style='time')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip',hue='sex',style='time',
               size='size')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# >* relplot -> figure level -> square shape(default size)

# %%
sns.relplot(data=tips, x='total_bill',y='tip', kind='scatter')

# %%
sns.relplot(data=tips, x='total_bill',y='tip', kind='scatter',hue='sex',
           style='time')

# %% [markdown]
# ### Line plot

# %%
gap = px.data.gapminder()
gap
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
temp_df = gap[gap['country'] == 'India']
temp_df
# Out:
#     country continent  year  lifeExp         pop    gdpPercap iso_alpha  \
# 696   India      Asia  1952   37.373   372000000   546.565749       IND
# 697   India      Asia  1957   40.249   409000000   590.061996       IND
# 698   India      Asia  1962   43.605   454000000   658.347151       IND
# 699   India      Asia  1967   47.193   506000000   700.770611       IND
# 700   India      Asia  1972   50.651   567000000   724.032527       IND
# 701   India      Asia  1977   54.208   634000000   813.337323       IND
# 702   India      Asia  1982   56.596   708000000   855.723538       IND
# 703   India      Asia  1987   58.553   788000000   976.512676       IND
# 704   India      Asia  1992   60.223   872000000  1164.406809       IND
# 705   India      Asia  1997   61.765   959000000  1458.817442       IND
# 706   India      Asia  2002   62.879  1034172547  1746.769454       IND
# 707   India      Asia  2007   64.698  1110396331  2452.210407       IND
#
#      iso_num
# 696      356
# ...

# %% [markdown]
# >* axes level function

# %%
sns.lineplot(data=temp_df, x='year', y='lifeExp')
# Out:
# <AxesSubplot:xlabel='year', ylabel='lifeExp'>

# %% [markdown]
# >* using relpplot (figure level)

# %%
sns.relplot(data=temp_df, x='year', y='lifeExp',kind='line')

# %%
gap['country'].isin(['India','Pakistan','China'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703    False
# Name: country, Length: 1704, dtype: bool

# %%
gap[gap['country'].isin(['India','Pakistan','China'])]
# Out:
#        country continent  year   lifeExp         pop    gdpPercap iso_alpha  \
# 288      China      Asia  1952  44.00000   556263527   400.448611       CHN
# 289      China      Asia  1957  50.54896   637408000   575.987001       CHN
# 290      China      Asia  1962  44.50136   665770000   487.674018       CHN
# 291      China      Asia  1967  58.38112   754550000   612.705693       CHN
# 292      China      Asia  1972  63.11888   862030000   676.900092       CHN
# 293      China      Asia  1977  63.96736   943455000   741.237470       CHN
# 294      China      Asia  1982  65.52500  1000281000   962.421381       CHN
# 295      China      Asia  1987  67.27400  1084035000  1378.904018       CHN
# 296      China      Asia  1992  68.69000  1164970000  1655.784158       CHN
# 297      China      Asia  1997  70.42600  1230075000  2289.234136       CHN
# 298      China      Asia  2002  72.02800  1280400000  3119.280896       CHN
# ...

# %%
temp_df = gap[gap['country'].isin(['India','Pakistan','China'])]

# %%
sns.relplot(data=temp_df, x='year', y='lifeExp',kind='line',hue='country')

# %% [markdown]
# >* **Note:** in figure level function we can see that it can place the legends outside the graph where as in axis level function legend will be inside the graph only. We can see that sns.relplot has a control over figure so it is more powerful in this kind of situation, whereas the axis level function like sns.lineplot has control only on the graph or axis area.

# %%
temp_df = gap[gap['country'].isin(['India','Brazil','Germany'])]
temp_df.head()
# Out:
#     country continent  year  lifeExp        pop    gdpPercap iso_alpha  \
# 168  Brazil  Americas  1952   50.917   56602560  2108.944355       BRA
# 169  Brazil  Americas  1957   53.285   65551171  2487.365989       BRA
# 170  Brazil  Americas  1962   55.665   76039390  3336.585802       BRA
# 171  Brazil  Americas  1967   57.632   88049823  3429.864357       BRA
# 172  Brazil  Americas  1972   59.504  100840058  4985.711467       BRA
#
#      iso_num
# 168       76
# 169       76
# 170       76
# 171       76
# 172       76

# %%
sns.relplot(data=temp_df, x='year', y='lifeExp',kind='line',hue='country',
           style='continent')

# %%
sns.relplot(data=temp_df, x='year', y='lifeExp',kind='line',hue='country',
           style='continent',size='continent')

# here size parameter will represent the thinness or thickness

# %% [markdown]
# ### facet plot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(data=tips,x='total_bill',y='tip',kind='scatter',col='sex')

# %%
sns.relplot(data=tips,x='total_bill',y='tip',kind='scatter',row='sex')

# %%
sns.relplot(data=tips,x='total_bill',y='tip',kind='scatter',col='smoker'
            ,row='sex')

# %%
sns.relplot(data=tips,x='total_bill',y='tip',kind='scatter',col='smoker'
            ,row='day')

# %% [markdown]
# >* **Note:** facet will work with only figure level functions. It will work with the relplot but it will not work with the scatter plot and line plot

# %% [markdown]
# ### col wrap

# %%
gap.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
sns.relplot(data=gap, x='lifeExp', y='gdpPercap', kind='scatter', col='year')

# here all graph will be in the one single column
# to solve this we can use the col_wrap parameter

# %%
sns.relplot(data=gap, x='lifeExp', y='gdpPercap', kind='scatter', col='year',
           col_wrap=3)

# %% [markdown]
# ## 2. `Distribution Plots`
#
# - used for univariate analysis
# - used to find out the distribution
# - Range of the observation
# - Central Tendency
# - is the data bimodal?
# - Are there outliers?
#
# Plots under distribution plot and this are axes level functions
#
# - histplot
# - kdeplot
# - rugplot
#
# figure level function
#
# - displot

# %% [markdown]
# ### histplot

# %% [markdown]
# >* plotting uninvariate histogram

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.histplot(data=tips, x='total_bill')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.displot(data=tips, x='total_bill', kind='hist')

# this is figure level function

# %%
sns.displot(data=tips, x='total_bill', kind='hist', bins=20)

# %% [markdown]
# >* It’s also possible to visualize the distribution of a categorical variable using the logic of a histogram. Discrete bins are automatically set for categorical variables
# >* **Note:** Technically this type of plot will not be called as histogram, it will be called as countplot

# %%
sns.displot(data=tips, x='day', kind='hist')

# %%
sns.displot(data=tips, x='tip', kind='hist', hue='sex')

# %% [markdown]
# >* element -->> step

# %%
sns.displot(data=tips, x='tip', kind='hist', hue='sex', element='step')

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.displot(data=titanic, x='age', kind='hist', element='step')

# %%
sns.displot(data=titanic, x='age', kind='hist', element='step', hue='sex')

# %% [markdown]
# >* facet using col and row
# >* this will not work on the histplot function because histplot is a axes level function

# %%
sns.displot(data=titanic, x='age', kind='hist', element='step', col='sex')

# %% [markdown]
# ### kdeplot - Kernel Density Estimation
# >* Rather than using discrete bins, a KDE plot smooths the observations with a Gaussian kernel, producing a continuous density estimate

# %%
sns.kdeplot(data=tips,x='total_bill')
# by using the axis level function
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.displot(data=tips,x='total_bill',kind='kde')
# by using the figure level function

# %% [markdown]
# >* hue -> fill

# %%
sns.displot(data=tips,x='total_bill',kind='kde',hue='sex')

# %%
sns.displot(data=tips,x='total_bill',kind='kde',hue='sex',fill=True)

# %% [markdown]
# >* we can not increase the size of the plot in figure level function as we do in the matplotlib library, here we will add two parameter to increase the size of the plot.
# >* one is height parameter and another one is aspect

# %%
sns.displot(data=tips,x='total_bill',kind='kde',hue='sex',fill=True,
            height=10,aspect=2)

# %% [markdown]
# ### rugplot
# >* Plot marginal distributions by drawing ticks along the x and y axes.
# >* This function is intended to complement other plots by showing the location of individual observations in an unobtrusive way.

# %%
sns.kdeplot(data=tips,x='total_bill')
sns.rugplot(data=tips,x='total_bill')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ### Bivariate histogram
# >* A bivariate histogram bins the data within rectangles that tile the plot and then shows the count of observations within each rectangle with the fill color

# %%
sns.histplot(data=tips, x='total_bill', y='tip')
# by using axes level function
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.displot(data=tips, x='total_bill', y='tip',kind='hist')
# by using the figure level function

# %% [markdown]
# ### Bivariate Kdeplot
# >* a bivariate KDE plot smoothes the (x, y) observations with a 2D Gaussian

# %%
sns.kdeplot(data=tips, x='total_bill', y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## 3. `Matrix Plot`
#
# - Heatmap
# - Clustermap

# %% [markdown]
# ### Heatmap
# >* Plot rectangular data as a color-encoded matrix

# %%
gap.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %% [markdown]
# >* we want to plot the year wise life expectancy of countries

# %%
temp_df = gap.pivot(index="country", columns="year", values="lifeExp")
temp_df
# Out:
# year                  1952    1957    1962    1967    1972    1977    1982  \
# country
# Afghanistan         28.801  30.332  31.997  34.020  36.088  38.438  39.854
# Albania             55.230  59.280  64.820  66.220  67.690  68.930  70.420
# Algeria             43.077  45.685  48.303  51.407  54.518  58.014  61.368
# Angola              30.015  31.999  34.000  35.985  37.928  39.483  39.942
# Argentina           62.485  64.399  65.142  65.634  67.065  68.481  69.942
# ...                    ...     ...     ...     ...     ...     ...     ...
# Vietnam             40.412  42.887  45.363  47.838  50.254  55.764  58.816
# West Bank and Gaza  43.160  45.671  48.127  51.631  56.532  60.765  64.406
# Yemen, Rep.         32.548  33.970  35.180  36.984  39.848  44.175  49.113
# Zambia              42.038  44.077  46.023  47.768  50.107  51.386  51.821
# Zimbabwe            48.451  50.469  52.358  53.995  55.635  57.674  60.363
#
# year                  1987    1992    1997    2002    2007
# ...

# %%
# heatmap is an axes level function
# here we can re size the graph by giving figure values same as matplotlib

plt.figure(figsize=(15,15))
sns.heatmap(temp_df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='country'>

# %% [markdown]
# >* annot

# %%
gap[gap['continent'] == 'Europe']
# Out:
#              country continent  year  lifeExp       pop     gdpPercap  \
# 12           Albania    Europe  1952   55.230   1282697   1601.056136
# 13           Albania    Europe  1957   59.280   1476505   1942.284244
# 14           Albania    Europe  1962   64.820   1728137   2312.888958
# 15           Albania    Europe  1967   66.220   1984060   2760.196931
# 16           Albania    Europe  1972   67.690   2263554   3313.422188
# ...              ...       ...   ...      ...       ...           ...
# 1603  United Kingdom    Europe  1987   75.007  56981620  21664.787670
# 1604  United Kingdom    Europe  1992   76.420  57866349  22705.092540
# 1605  United Kingdom    Europe  1997   77.218  58808266  26074.531360
# 1606  United Kingdom    Europe  2002   78.471  59912431  29478.999190
# 1607  United Kingdom    Europe  2007   79.425  60776238  33203.261280
#
#      iso_alpha  iso_num
# 12         ALB        8
# 13         ALB        8
# 14         ALB        8
# 15         ALB        8
# ...

# %%
gap[gap['continent'] == 'Europe'].pivot(
    index="country", columns="year", values="lifeExp")
# Out:
# year                      1952    1957    1962    1967    1972    1977  \
# country
# Albania                 55.230  59.280  64.820  66.220  67.690  68.930
# Austria                 66.800  67.480  69.540  70.140  70.630  72.170
# Belgium                 68.000  69.240  70.250  70.940  71.440  72.800
# Bosnia and Herzegovina  53.820  58.450  61.930  64.790  67.450  69.860
# Bulgaria                59.600  66.610  69.510  70.420  70.900  70.810
# Croatia                 61.210  64.770  67.130  68.500  69.610  70.640
# Czech Republic          66.870  69.030  69.900  70.380  70.290  70.710
# Denmark                 70.780  71.810  72.350  72.960  73.470  74.690
# Finland                 66.550  67.490  68.750  69.830  70.870  72.520
# France                  67.410  68.930  70.510  71.550  72.380  73.830
# Germany                 67.500  69.100  70.300  70.800  71.000  72.500
# Greece                  65.860  67.860  69.510  71.000  72.340  73.680
# ...

# %%
temp_df = gap[gap['continent'] == 'Europe'].pivot(
    index="country", columns="year", values="lifeExp")

# %%
plt.figure(figsize=(15,15))
sns.heatmap(temp_df, annot=True)

# to give the annotation of the values we wil use the annot parameter
# Out:
# <AxesSubplot:xlabel='year', ylabel='country'>

# %%
plt.figure(figsize=(15,15))
sns.heatmap(temp_df, annot=True, linewidth=0.7, cmap='winter')

# we are using the linewidth parameter to improve readability of heatmap
# cmap is for changin the colour gradient of the graph
# Out:
# <AxesSubplot:xlabel='year', ylabel='country'>

# %% [markdown]
# ### Clustermap
# >* Plot a matrix dataset as a hierarchically-clustered heatmap.
# >* This function requires scipy to be available.

# %%
iris = px.data.iris()
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# ...

# %%
sns.clustermap(iris.iloc[:,[0,1,2,3]])
